# %% [markdown]
# <a href="https://colab.research.google.com/github/heydi98-hl/datamining/blob/main/Ejercicio3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/heydi98-hl/datamining/refs/heads/main/Archivo/Ejercicio%203.csv")

df.head()
# Out:
#    Weight  Cholesterol  Gender
# 0     102          111       1
# 1     115          135       1
# 2     115          136       1
# 3     140          167       0
# 4     130          158       1

# %% [markdown]
# validacion de dimensiones

# %%
df.shape
# Out:
# (547, 3)

# %%
#. Revisión de tipos de datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Weight       547 non-null    int64
#  1   Cholesterol  547 non-null    int64
#  2   Gender       547 non-null    int64
# dtypes: int64(3)
# memory usage: 12.9 KB

# %%
#revision de valores nulos
df.isnull().sum()
# Out:
# Weight         0
# Cholesterol    0
# Gender         0
# dtype: int64

# %%
#Revision de regitros duplicados
df.duplicated().sum()
# Out:
# np.int64(57)

# %%
#Estadistica descriptiva
df.describe()
# Out:
#            Weight  Cholesterol      Gender
# count  547.000000   547.000000  547.000000
# mean   143.572212   170.433272    0.513711
# std     30.837275    39.147189    0.500269
# min     95.000000   102.000000    0.000000
# 25%    116.000000   136.000000    0.000000
# 50%    140.000000   169.000000    1.000000
# 75%    171.000000   208.000000    1.000000
# max    203.000000   235.000000    1.000000

# %%
#Distribucion de genero
df["Gender"].value_counts()
# Out:
# Gender
# 1    281
# 0    266
# Name: count, dtype: int64

# %%
#Revision de valores atipicos
variables_numericas = ["Weight", "Cholesterol"]

for columna in variables_numericas:
    media = df[columna].mean()
    desviacion = df[columna].std()

    limite_inferior = media - 2 * desviacion
    limite_superior = media + 2 * desviacion

    atipicos = df[
        (df[columna] < limite_inferior) |
        (df[columna] > limite_superior)
    ]

    print("Variable:", columna)
    print("Media:", round(media, 2))
    print("Desviación estándar:", round(desviacion, 2))
    print("Límite inferior:", round(limite_inferior, 2))
    print("Límite superior:", round(limite_superior, 2))
    print("Cantidad de valores atípicos:", len(atipicos))
# Out:
# Variable: Weight
# Media: 143.57
# Desviación estándar: 30.84
# Límite inferior: 81.9
# Límite superior: 205.25
# Cantidad de valores atípicos: 0
# Variable: Cholesterol
# Media: 170.43
# Desviación estándar: 39.15
# Límite inferior: 92.14
# Límite superior: 248.73
# Cantidad de valores atípicos: 0

# %%
from sklearn.cluster import KMeans

X = df[["Weight", "Cholesterol", "Gender"]]

modelo_k2 = KMeans(n_clusters=2, random_state=0, n_init=10)
df["cluster_k2"] = modelo_k2.fit_predict(X)

centroides_k2 = pd.DataFrame(modelo_k2.cluster_centers_, columns=X.columns)
print(centroides_k2)
# Out:
#        Weight  Cholesterol    Gender
# 0  119.073826   139.348993  0.479866
# 1  172.891566   207.634538  0.554217

# %%
modelo_k4 = KMeans(n_clusters=4, random_state=0, n_init=10)
df["cluster_k4"] = modelo_k4.fit_predict(X)

centroides_k4 = pd.DataFrame(modelo_k4.cluster_centers_, columns=X.columns)
print(centroides_k4)
print(df["cluster_k4"].value_counts())
# Out:
#        Weight  Cholesterol    Gender
# 0  127.725926   154.385185  0.459259
# 1  184.318182   218.915584  0.590909
# 2  106.850000   119.535714  0.542857
# 3  152.093220   185.906780  0.440678
# cluster_k4
# 1    154
# 2    140
# 0    135
# 3    118
# Name: count, dtype: int64

# %%
grupo_riesgo = df[df["cluster_k4"] == 1]

print(grupo_riesgo[["Weight", "Cholesterol", "Gender"]].describe())
print(grupo_riesgo[["Weight", "Cholesterol"]].min())
# Out:
#            Weight  Cholesterol      Gender
# count  154.000000   154.000000  154.000000
# mean   184.318182   218.915584    0.590909
# std      9.809096     8.190502    0.493270
# min    167.000000   204.000000    0.000000
# 25%    176.250000   212.250000    0.000000
# 50%    183.500000   220.000000    1.000000
# 75%    191.000000   225.000000    1.000000
# max    203.000000   235.000000    1.000000
# Weight         167
# Cholesterol    204
# dtype: int64

# %%
# Filtrar empleados/personas asignadas al clúster de mayor riesgo
personas_riesgo = df[df["cluster_k4"] == 1]

# Guardar el resultado para revisión o uso posterior
personas_riesgo.to_csv("personas_riesgo_cluster_kmeans.csv", index=False)

# Criterio mínimo observado en el clúster de riesgo
peso_minimo = personas_riesgo["Weight"].min()
colesterol_minimo = personas_riesgo["Cholesterol"].min()

print(peso_minimo, colesterol_minimo)
# Out:
# 167 204

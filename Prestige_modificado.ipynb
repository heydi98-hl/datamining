# %% [markdown]
# <a href="https://colab.research.google.com/github/heydi98-hl/datamining/blob/main/Prestige_modificado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from itertools import combinations

# %%
url="https://raw.githubusercontent.com/heydi98-hl/datamining/refs/heads/main/Archivo/Prestige_modificado.csv"
df = pd.read_csv(url)
df.head()
# Out:
#   occupation;education;income;women;prestige;census;type_num
# 0   gov.administrators;13.11;12351;11.16;68.8;1113;1
# 1      general.managers;12.26;25879;4.02;69.1;1130;1
# 2            accountants;12.77;9271;15.7;63.4;1171;1
# 3    purchasing.officers;11.42;8865;9.11;56.8;1175;1
# 4              chemists;14.62;8403;11.68;73.5;2111;1

# %%
print(df.shape)
# Out:
# (102, 1)

# %%
print(df.head())
# Out:
#   occupation;education;income;women;prestige;census;type_num
# 0   gov.administrators;13.11;12351;11.16;68.8;1113;1
# 1      general.managers;12.26;25879;4.02;69.1;1130;1
# 2            accountants;12.77;9271;15.7;63.4;1171;1
# 3    purchasing.officers;11.42;8865;9.11;56.8;1175;1
# 4              chemists;14.62;8403;11.68;73.5;2111;1

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 1 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   occupation;education;income;women;prestige;census;type_num  102 non-null    object
# dtypes: object(1)
# memory usage: 948.0+ bytes
# None

# %%
print(df.isnull().sum())
# Out:
# occupation;education;income;women;prestige;census;type_num    0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df.describe())
# Out:
#        occupation;education;income;women;prestige;census;type_num
# count                                                 102
# unique                                                102
# top      gov.administrators;13.11;12351;11.16;68.8;1113;1
# freq                                                    1
